# %% [markdown]
# # Data handling
# Ignore cells with a borough that is Not assigned
#
# More than one neighborhood can exist in one postal code; these will be combined with the neighborhoods separated with a comma
#
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
# bs4 ref: https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3
# bs4 ref: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

import pandas as pd
from bs4 import BeautifulSoup
import requests

result = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(result.text, 'lxml')
table_list = soup.find("table", class_ = "wikitable sortable")

PostalCode = []
Borough = []
Neighborhood = []

for entry in table_list.find_all('tr'):
    items = entry.find_all('td')
    if len(items) == 3:
        PostalCode.append(items[0].text)
        Borough.append(items[1].text)
        Neighborhood.append(items[2].text[:-1])   # to remove \n

df = pd.DataFrame({"PostalCode":PostalCode, "Borough":Borough, "Neighborhood":Neighborhood})

# Ignore cells with a borough that is Not assigned
df = df[df.Borough != "Not assigned"]

# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
loc = df.Neighborhood == "Not assigned"
df["Neighborhood"][loc] = df["Borough"][loc]

# More than one neighborhood can exist in one postal code; these will be combined with the neighborhoods separated with a comma
df_final = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood"])

for name, group in df.groupby("PostalCode"):
    neighborhoods = ", ".join(group["Neighborhood"])
    df_final = df_final.append({"PostalCode":list(group["PostalCode"])[0], "Borough":list(group["Borough"])[0], "Neighborhood":neighborhoods}, ignore_index=True)

print(df_final.shape)
print(df_final.head())
# Out:
# (103, 3)
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# # Get the latitude and the longitude coordinates of each neighborhood

# %%
df_coords = pd.read_csv("Geospatial_Coordinates.csv")
df_full = pd.merge(df_final, df_coords, left_on='PostalCode', right_on='Postal Code')
display(df_full)
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 0                                       Rouge, Malvern         M1B  43.806686
# 1               Highland Creek, Rouge Hill, Port Union         M1C  43.784535
# 2                    Guildwood, Morningside, West Hill         M1E  43.763573
# 3                                               Woburn         M1G  43.770992
# 4                                            Cedarbrae         M1H  43.773136
# 5                                  Scarborough Village         M1J  43.744734
# 6          East Birchmount Park, Ionview, Kennedy Park         M1K  43.727929
# 7                      Clairlea, Golden Mile, Oakridge         M1L  43.711112
# 8      Cliffcrest, Cliffside, Scarborough Village West         M1M  43.716316
# 9                          Birch Cliff, Cliffside West         M1N  43.692657
# 10   Dorset Park, Scarborough Town Centre, Wexford ...         M1P  43.757410
# 11                                   Maryvale, Wexford         M1R  43.750072
# 12                                           Agincourt         M1S  43.794200
# 13             Clarks Corners, Sullivan, Tam O'Shanter         M1T  43.781638
# 14   Agincourt North, L'Amoreaux East, Milliken, St...         M1V  43.815252
# 15                       L'Amoreaux West, Steeles West         M1W  43.799525
# 16                                         Upper Rouge         M1X  43.836125
# 17                                   Hillcrest Village         M2H  43.803762
# 18                        Fairview, Henry Farm, Oriole         M2J  43.778517
# 19                                     Bayview Village         M2K  43.786947
# 20                            Silver Hills, York Mills         M2L  43.757490
# 21                             Newtonbrook, Willowdale         M2M  43.789053
# 22                                    Willowdale South         M2N  43.770120
# 23                                     York Mills West         M2P  43.752758
# 24                                     Willowdale West         M2R  43.782736
# 25                                           Parkwoods         M3A  43.753259
# 26                                     Don Mills North         M3B  43.745906
# 27                    Flemingdon Park, Don Mills South         M3C  43.725900
# 28     Bathurst Manor, Downsview North, Wilson Heights         M3H  43.754328
# 29                     Northwood Park, York University         M3J  43.767980
# ..                                                 ...         ...        ...
# 73                                  Humewood-Cedarvale         M6C  43.693781
# 74                                 Caledonia-Fairbanks         M6E  43.689026
# 75                                            Christie         M6G  43.669542
# 76                        Dovercourt Village, Dufferin         M6H  43.669005
# 77                            Little Portugal, Trinity         M6J  43.647927
# 78        Brockton, Exhibition Place, Parkdale Village         M6K  43.636847
# 79            Maple Leaf Park, North Park, Upwood Park         M6L  43.713756
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn         M6M  43.691116
# 81                       The Junction North, Runnymede         M6N  43.673185
# 82                       High Park, The Junction South         M6P  43.661608
# 83                              Parkdale, Roncesvalles         M6R  43.648960
# 84                                  Runnymede, Swansea         M6S  43.651571
# 85                                        Queen's Park         M7A  43.662301
# 86               Canada Post Gateway Processing Centre         M7R  43.636966
# 87   Business Reply Mail Processing Centre 969 Eastern         M7Y  43.662744
# 88        Humber Bay Shores, Mimico South, New Toronto         M8V  43.605647
# 89                              Alderwood, Long Branch         M8W  43.602414
# 90       The Kingsway, Montgomery Road, Old Mill North         M8X  43.653654
# 91   Humber Bay, King's Mill Park, Kingsway Park So...         M8Y  43.636258
# 92   Kingsway Park South West, Mimico NW, The Queen...         M8Z  43.628841
# 93                                    Islington Avenue         M9A  43.667856
# 94   Cloverdale, Islington, Martin Grove, Princess ...         M9B  43.650943
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...         M9C  43.643515
# 96                                       Humber Summit         M9L  43.756303
# 97                                    Emery, Humberlea         M9M  43.724766
# 98                                              Weston         M9N  43.706876
# 99                                           Westmount         M9P  43.696319
# 100  Kingsview Village, Martin Grove Gardens, Richv...         M9R  43.688905
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...         M9V  43.739416
# 102                                          Northwest         M9W  43.706748
#
#      Longitude
# 0   -79.194353
# 1   -79.160497
# 2   -79.188711
# 3   -79.216917
# 4   -79.239476
# 5   -79.239476
# 6   -79.262029
# 7   -79.284577
# 8   -79.239476
# 9   -79.264848
# 10  -79.273304
# 11  -79.295849
# 12  -79.262029
# 13  -79.304302
# 14  -79.284577
# 15  -79.318389
# 16  -79.205636
# 17  -79.363452
# 18  -79.346556
# 19  -79.385975
# 20  -79.374714
# 21  -79.408493
# 22  -79.408493
# 23  -79.400049
# 24  -79.442259
# 25  -79.329656
# 26  -79.352188
# 27  -79.340923
# 28  -79.442259
# 29  -79.487262
# ..         ...
# 73  -79.428191
# 74  -79.453512
# 75  -79.422564
# 76  -79.442259
# 77  -79.419750
# 78  -79.428191
# 79  -79.490074
# 80  -79.476013
# 81  -79.487262
# 82  -79.464763
# 83  -79.456325
# 84  -79.484450
# 85  -79.389494
# 86  -79.615819
# 87  -79.321558
# 88  -79.501321
# 89  -79.543484
# 90  -79.506944
# 91  -79.498509
# 92  -79.520999
# 93  -79.532242
# 94  -79.554724
# 95  -79.577201
# 96  -79.565963
# 97  -79.532242
# 98  -79.518188
# 99  -79.532242
# 100 -79.554724
# 101 -79.588437
# 102 -79.594054
#
# [103 rows x 6 columns]

# %% [markdown]
# # Work with only boroughs that contain the word Toronto
# # Cluster into 5 chunks

# %%
import json, requests

def getNearbyVenues(names, latitudes, longitudes, radius=500, limit=5):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            'B0LPCPNQLDCNHSV3KLKMLY0XMKD0NGH40ZJZM2DSM3FNHBTC', 
            '2SJFKJTXBG4D21XFM5S2JP5IZRMV0LVOQ3UZRP0YLDWVHJW3', 
            '20180323', 
            lat, 
            lng, 
            radius, 
            limit)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
df_toronto = df_full[df_full["Borough"].str.contains("Toronto")]
toronto_venues = getNearbyVenues(names=df_toronto['Neighborhood'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )

# %%
import numpy as np

kclusters = 5
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
#display(toronto_venues)
# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()


def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# display(neighborhoods_venues_sorted.head())

from sklearn.cluster import KMeans

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)   # run k-means clustering
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)   # add clustering labels

toronto_merged = df_toronto

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.sort_values('Cluster Labels', inplace=True)
toronto_merged.reset_index(inplace=True, drop=True)
display(toronto_merged)
# Out:
#    PostalCode           Borough  \
# 0         M4T   Central Toronto
# 1         M5H  Downtown Toronto
# 2         M6P      West Toronto
# 3         M6J      West Toronto
# 4         M6H      West Toronto
# 5         M5W  Downtown Toronto
# 6         M5V  Downtown Toronto
# 7         M5R   Central Toronto
# 8         M5P   Central Toronto
# 9         M5J  Downtown Toronto
# 10        M5E  Downtown Toronto
# 11        M5B  Downtown Toronto
# 12        M7Y      East Toronto
# 13        M4K      East Toronto
# 14        M4W  Downtown Toronto
# 15        M4L      East Toronto
# 16        M4N   Central Toronto
# 17        M4P   Central Toronto
# 18        M4Y  Downtown Toronto
# 19        M5A  Downtown Toronto
# 20        M6K      West Toronto
# 21        M4M      East Toronto
# 22        M6G  Downtown Toronto
# 23        M5T  Downtown Toronto
# 24        M4E      East Toronto
# 25        M4V   Central Toronto
# 26        M6S      West Toronto
# 27        M5G  Downtown Toronto
# 28        M4R   Central Toronto
# 29        M4S   Central Toronto
# 30        M5L  Downtown Toronto
# 31        M5K  Downtown Toronto
# 32        M5X  Downtown Toronto
# 33        M5C  Downtown Toronto
# 34        M4X  Downtown Toronto
# 35        M6R      West Toronto
# 36        M5S  Downtown Toronto
# 37        M5N   Central Toronto
#
#                                          Neighborhood Postal Code   Latitude  \
# 0                         Moore Park, Summerhill East         M4T  43.689574
# 1                            Adelaide, King, Richmond         M5H  43.650571
# 2                       High Park, The Junction South         M6P  43.661608
# 3                            Little Portugal, Trinity         M6J  43.647927
# 4                        Dovercourt Village, Dufferin         M6H  43.669005
# 5                     Stn A PO Boxes 25 The Esplanade         M5W  43.646435
# 6   CN Tower, Bathurst Quay, Island airport, Harbo...         M5V  43.628947
# 7                 The Annex, North Midtown, Yorkville         M5R  43.672710
# 8                 Forest Hill North, Forest Hill West         M5P  43.696948
# 9   Harbourfront East, Toronto Islands, Union Station         M5J  43.640816
# 10                                        Berczy Park         M5E  43.644771
# 11                           Ryerson, Garden District         M5B  43.657162
# 12  Business Reply Mail Processing Centre 969 Eastern         M7Y  43.662744
# 13                       The Danforth West, Riverdale         M4K  43.679557
# 14                                           Rosedale         M4W  43.679563
# 15                     The Beaches West, India Bazaar         M4L  43.668999
# 16                                      Lawrence Park         M4N  43.728020
# 17                                   Davisville North         M4P  43.712751
# 18                               Church and Wellesley         M4Y  43.665860
# 19                          Harbourfront, Regent Park         M5A  43.654260
# 20       Brockton, Exhibition Place, Parkdale Village         M6K  43.636847
# 21                                    Studio District         M4M  43.659526
# 22                                           Christie         M6G  43.669542
# 23          Chinatown, Grange Park, Kensington Market         M5T  43.653206
# 24                                        The Beaches         M4E  43.676357
# 25  Deer Park, Forest Hill SE, Rathnelly, South Hi...         M4V  43.686412
# 26                                 Runnymede, Swansea         M6S  43.651571
# 27                                 Central Bay Street         M5G  43.657952
# 28                                 North Toronto West         M4R  43.715383
# 29                                         Davisville         M4S  43.704324
# 30                     Commerce Court, Victoria Hotel         M5L  43.648198
# 31           Design Exchange, Toronto Dominion Centre         M5K  43.647177
# 32             First Canadian Place, Underground city         M5X  43.648429
# 33                                     St. James Town         M5C  43.651494
# 34                        Cabbagetown, St. James Town         M4X  43.667967
# 35                             Parkdale, Roncesvalles         M6R  43.648960
# 36                     Harbord, University of Toronto         M5S  43.662696
# 37                                           Roselawn         M5N  43.711695
#
#     Longitude  Cluster Labels          1st Most Common Venue  \
# 0  -79.383160               0                     Playground
# 1  -79.384568               1               Greek Restaurant
# 2  -79.464763               1                      Gastropub
# 3  -79.419750               1                 Ice Cream Shop
# 4  -79.442259               1                            Bar
# 5  -79.374846               1                         Museum
# 6  -79.394420               1                        Airport
# 7  -79.405678               1  Vegetarian / Vegan Restaurant
# 8  -79.411307               1                          Trail
# 9  -79.381752               1                    Salad Place
# 10 -79.373306               1                         Museum
# 11 -79.378937               1                 Clothing Store
# 12 -79.321558               1                     Comic Shop
# 13 -79.352188               1               Greek Restaurant
# 14 -79.377529               1                           Park
# 15 -79.315572               1                 Ice Cream Shop
# 16 -79.388790               1                    Swim School
# 17 -79.390197               1              Food & Drink Shop
# 18 -79.383160               1                      Bookstore
# 19 -79.360636               2                    Coffee Shop
# 20 -79.428191               2                    Coffee Shop
# 21 -79.340923               2                 Sandwich Place
# 22 -79.422564               2                    Coffee Shop
# 23 -79.400049               2                Organic Grocery
# 24 -79.293031               2                    Coffee Shop
# 25 -79.400049               2                    Coffee Shop
# 26 -79.484450               2                           Food
# 27 -79.387383               2                    Coffee Shop
# 28 -79.405678               2                    Yoga Studio
# 29 -79.388790               3                   Dessert Shop
# 30 -79.379817               3                           Café
# 31 -79.381576               3                     Restaurant
# 32 -79.382280               3                     Restaurant
# 33 -79.375418               3                    Coffee Shop
# 34 -79.367675               3              Indian Restaurant
# 35 -79.456325               3                  Movie Theater
# 36 -79.400049               3            Japanese Restaurant
# 37 -79.416936               4                         Garden
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0   Vegetarian / Vegan Restaurant          Dance Studio
# 1                    Concert Hall            Steakhouse
# 2                       Speakeasy                  Park
# 3                     Pizza Place     Korean Restaurant
# 4                     Supermarket               Brewery
# 5                 Thai Restaurant          Cocktail Bar
# 6              Airport Food Court        Airport Lounge
# 7             American Restaurant                  Park
# 8                Sushi Restaurant              Bus Line
# 9                            Park                  Lake
# 10                Thai Restaurant          Liquor Store
# 11                     Comic Shop           Pizza Place
# 12                    Pizza Place        Farmers Market
# 13             Italian Restaurant        Cosmetics Shop
# 14                          Trail            Playground
# 15             Italian Restaurant                   Gym
# 16                           Park              Bus Line
# 17                           Park                 Hotel
# 18                Bubble Tea Shop      Ramen Restaurant
# 19                 Breakfast Spot  Gym / Fitness Center
# 20                            Bar  Caribbean Restaurant
# 21                 Ice Cream Shop             Bookstore
# 22                  Grocery Store                  Café
# 23            Arts & Crafts Store    Mexican Restaurant
# 24              Health Food Store                   Pub
# 25               Sushi Restaurant           Supermarket
# 26               Sushi Restaurant                  Café
# 27                      Gastropub    Italian Restaurant
# 28            Sporting Goods Shop                   Spa
# 29              Indian Restaurant    Italian Restaurant
# 30                            Gym  Gym / Fitness Center
# 31                           Café                   Gym
# 32                           Café                   Gym
# 33                       Creperie   Japanese Restaurant
# 34                          Diner   Japanese Restaurant
# 35                        Dog Run          Dessert Shop
# 36             Italian Restaurant                Bakery
# 37                   Home Service          Dessert Shop
#
#             4th Most Common Venue          5th Most Common Venue
# 0                     Coffee Shop                     Comic Shop
# 1                           Plaza                          Hotel
# 2              Italian Restaurant                            Bar
# 3                Asian Restaurant                        Brewery
# 4                          Bakery      Middle Eastern Restaurant
# 5                      Steakhouse                   Concert Hall
# 6                Airport Terminal                Harbor / Marina
# 7                            Café              Indian Restaurant
# 8                   Jewelry Store  Vegetarian / Vegan Restaurant
# 9             Sporting Goods Shop  Vegetarian / Vegan Restaurant
# 10                     Steakhouse                   Concert Hall
# 11                  Burrito Place                          Plaza
# 12                  Burrito Place                        Brewery
# 13                 Ice Cream Shop                     Comic Shop
# 14  Vegetarian / Vegan Restaurant               Cuban Restaurant
# 15              Fish & Chips Shop                   Burger Joint
# 16             Dim Sum Restaurant  Vegetarian / Vegan Restaurant
# 17                 Sandwich Place                 Breakfast Spot
# 18                   Dance Studio                 Breakfast Spot
# 19                            Spa                         Bakery
# 20                            Gym                   Dessert Shop
# 21                    Coffee Shop                    Fish Market
# 22                          Diner             Italian Restaurant
# 23                           Café                    Coffee Shop
# 24  Vegetarian / Vegan Restaurant                   Dance Studio
# 25              Convenience Store            American Restaurant
# 26              Fish & Chips Shop                      Bookstore
# 27                     Comic Shop                   Concert Hall
# 28                          Diner             Salon / Barbershop
# 29                           Café                     Comic Shop
# 30                     Restaurant  Vegetarian / Vegan Restaurant
# 31                         Bakery                          Hotel
# 32           Gym / Fitness Center                         Bakery
# 33                     Restaurant             Italian Restaurant
# 34                     Restaurant             Italian Restaurant
# 35                     Restaurant               Cuban Restaurant
# 36                   Dessert Shop                     Restaurant
# 37                     Comic Shop                   Concert Hall

# %% [markdown]
# # Visualization & Conclusion
#
# k (# of clusters) is set to 5.
#
# Main conclusion is that, unless FourSquare query limit is limited to a smaller number (<10), there is usually just one big cluster (areas with cafe/coffee shop vs ones without).
#
# We got somewhat interesting result when we reduced the query limit to 5.
#
# However, there needs to be an extra interpreative layer to translate FourSquare categories for the output to be useful (e.g., cafe grouped with coffee shop, combine various ethnic resturants, fine tune differences between board categoreis of "diner", "restaurant", etc.). There is also (apparently) an inherent limiated to using k-means clustering to categorical (0 or 1) variables instead of continous variables.
#
# With that said, we observe the following...
# Cluster 0 & 4 has the unique profile that 3 of the top 5 results are non-food, and no coffee shops & cafes
# Cluster 1 contains mostly food places with very little cafes and coffee shops
# Cluster 2 tends to contain coffee shops & cafes
# Cluster 3 tends to contain coffee shops & cafes along with ethnic resaturants or gyms

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

map_clusters = folium.Map(location=[43.6658599, -79.3831599], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
